# %% [markdown]
# <a href="https://colab.research.google.com/github/Mbashas/data_decisions/blob/main/malaria_retrain_v2_fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🦟 Malaria Detection: Hypothesis-Driven Retraining (v2)
#
# ## What's Different from Baseline?
#
# | Setting | Baseline | This Experiment | Hypothesis |
# |---------|----------|-----------------|------------|
# | Model | YOLOv8**n** (3M params) | YOLOv8**s** (11M params) | H1: More capacity |
# | Epochs | 50 | 100 | H2: Reduce underfitting |
# | Image size | 640px | 1280px | H3: Better small object detection |
#
# **Research Question:** Can we improve parasite detection with a larger model, and does it help with domain shift (thin → thick)?
#
# ---

# %% [markdown]
# ## 1. Setup

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
print("✓ Drive mounted!")
# Out:
# Mounted at /content/drive
# ✓ Drive mounted!

# %%
# Install required packages
# !pip install ultralytics -q
# !pip install grad-cam -q

print("✓ Packages installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 111.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for grad-cam (pyproject.toml) ... done
# ✓ Packages installed!

# %%
# Verify GPU availability
import torch

if torch.cuda.is_available():
    print(f"✓ GPU Available: {torch.cuda.get_device_name(0)}")
    print(f"  Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("✗ No GPU! Go to: Runtime → Change runtime type → L4 GPU")
# Out:
# ✓ GPU Available: NVIDIA A100-SXM4-80GB
#   Memory: 85.2 GB

# %% [markdown]
# ## 2. Configuration
#
# **Uses your exact paths from the baseline experiment.**

# %%
# ============================================================================
# CONFIGURATION - SAME PATHS AS YOUR BASELINE
# ============================================================================

import os
from datetime import datetime

# Your existing dataset location on Drive (SAME AS BASELINE)
DRIVE_ROOT = "/content/drive/MyDrive/Datasets"

# Source paths (SAME AS BASELINE)
THIN_IMAGES_SRC = f"{DRIVE_ROOT}/Thin Images With Annotations/Thin Images Ghana/images"
THIN_LABELS_SRC = f"{DRIVE_ROOT}/Thin Images With Annotations/Thin Images Ghana/labels_yolo"
THICK_IMAGES_SRC = f"{DRIVE_ROOT}/Ghana/Thick/images"
THICK_LABELS_SRC = f"{DRIVE_ROOT}/Ghana/Thick/labels_yolo"

# Output paths (SAME AS BASELINE)
OUTPUT_ROOT = f"{DRIVE_ROOT}/malaria_yolo_ready"
RESULTS_DIR = f"{DRIVE_ROOT}/malaria_results"

# ============================================================================
# WHAT'S CHANGED FOR THIS EXPERIMENT
# ============================================================================

# Baseline values (for comparison)
BASELINE_MODEL_SIZE = "n"   # YOLOv8n
BASELINE_EPOCHS = 50
BASELINE_IMAGE_SIZE = 640

# NEW values for this experiment
MODEL_SIZE = "s"            # YOLOv8s (CHANGED: H1 - more capacity)
EPOCHS = 100                # (CHANGED: H2 - reduce underfitting)
IMAGE_SIZE = 1280           # (CHANGED: H3 - better small object detection)
BATCH_SIZE = 16              # Reduced due to larger image size and model
PATIENCE = 20               # Early stopping patience

# Experiment name for this run
EXPERIMENT_NAME = "retrain_v2_yolov8s_100ep_1280px"

# Class names (SAME AS BASELINE - 6 classes)
CLASS_NAMES = {
    0: "gametocyte",
    1: "trophozoite",
    2: "other_stage",
    3: "white_blood_cell",
    4: "artefacts",
    5: "ring_stage"
}

print("Configuration set!")
print("\n" + "="*60)
print("CHANGES FROM BASELINE:")
print("="*60)
print(f"Model:      YOLOv8{BASELINE_MODEL_SIZE} → YOLOv8{MODEL_SIZE}")
print(f"Epochs:     {BASELINE_EPOCHS} → {EPOCHS}")
print(f"Image size: {BASELINE_IMAGE_SIZE} → {IMAGE_SIZE}")
print(f"Batch size: auto → {BATCH_SIZE}")
# Out:
# Configuration set!
#
# ============================================================
# CHANGES FROM BASELINE:
# ============================================================
# Model:      YOLOv8n → YOLOv8s
# Epochs:     50 → 100
# Image size: 640 → 1280
# Batch size: auto → 16

# %%
# Verify your source paths exist (SAME CHECK AS BASELINE)
print("Checking your dataset paths...\n")

paths = [
    ("Thin Images", THIN_IMAGES_SRC),
    ("Thin Labels", THIN_LABELS_SRC),
    ("Thick Images", THICK_IMAGES_SRC),
    ("Thick Labels", THICK_LABELS_SRC),
    ("YOLO-Ready Data", OUTPUT_ROOT),
]

all_ok = True
for name, path in paths:
    if os.path.exists(path):
        count = len(os.listdir(path)) if os.path.isdir(path) else 1
        print(f"✓ {name}: {count} files/folders")
    else:
        print(f"✗ {name}: NOT FOUND")
        print(f"  Expected: {path}")
        all_ok = False

if all_ok:
    print("\n✓ All paths found! Ready to proceed.")
else:
    print("\n⚠️ Some paths not found. Check DRIVE_ROOT in the config above.")
# Out:
# Checking your dataset paths...
#
# ✓ Thin Images: 1011 files/folders
# ✓ Thin Labels: 1011 files/folders
# ✓ Thick Images: 3045 files/folders
# ✓ Thick Labels: 3045 files/folders
# ✓ YOLO-Ready Data: 4 files/folders
#
# ✓ All paths found! Ready to proceed.

# %% [markdown]
# ## 3. Check Existing YOLO Dataset
#
# Your baseline already created the YOLO-formatted dataset in `malaria_yolo_ready/`. We'll use that.

# %%
# Check the YOLO-ready dataset structure
print("Checking YOLO-ready dataset structure...\n")

yolo_paths = [
    f"{OUTPUT_ROOT}/thin_smear/train/images",
    f"{OUTPUT_ROOT}/thin_smear/train/labels",
    f"{OUTPUT_ROOT}/thin_smear/val/images",
    f"{OUTPUT_ROOT}/thin_smear/val/labels",
    f"{OUTPUT_ROOT}/thick_smear_test/images",
    f"{OUTPUT_ROOT}/thick_smear_test/labels",
]

for path in yolo_paths:
    if os.path.exists(path):
        count = len([f for f in os.listdir(path) if not f.startswith('.')])
        print(f"✓ {path.split('/')[-3]}/{path.split('/')[-2]}/{path.split('/')[-1]}: {count} files")
    else:
        print(f"✗ Missing: {path}")
# Out:
# Checking YOLO-ready dataset structure...
#
# ✓ thin_smear/train/images: 808 files
# ✓ thin_smear/train/labels: 808 files
# ✓ thin_smear/val/images: 203 files
# ✓ thin_smear/val/labels: 203 files
# ✓ malaria_yolo_ready/thick_smear_test/images: 3045 files
# ✓ malaria_yolo_ready/thick_smear_test/labels: 3045 files

# %%
# Count training and validation images
train_images_path = f"{OUTPUT_ROOT}/thin_smear/train/images"
val_images_path = f"{OUTPUT_ROOT}/thin_smear/val/images"
test_images_path = f"{OUTPUT_ROOT}/thick_smear_test/images"

train_n = len([f for f in os.listdir(train_images_path) if not f.startswith('.')]) if os.path.exists(train_images_path) else 0
val_n = len([f for f in os.listdir(val_images_path) if not f.startswith('.')]) if os.path.exists(val_images_path) else 0
test_n = len([f for f in os.listdir(test_images_path) if not f.startswith('.')]) if os.path.exists(test_images_path) else 0

print(f"\nDataset Summary:")
print(f"  Training (thin):   {train_n} images")
print(f"  Validation (thin): {val_n} images")
print(f"  Test (thick/OOD):  {test_n} images")
# Out:
# Dataset Summary:
#   Training (thin):   808 images
#   Validation (thin): 203 images
#   Test (thick/OOD):  3045 images

# %% [markdown]
# ## 4. Create data.yaml for Training

# %%
# Create data.yaml for thin smear training
thin_data_yaml = f"""
# Thin Smear Dataset for YOLO Training
# Experiment: {EXPERIMENT_NAME}

path: {OUTPUT_ROOT}/thin_smear
train: train/images
val: val/images

# Classes (same as baseline)
names:
  0: gametocyte
  1: trophozoite
  2: other_stage
  3: white_blood_cell
  4: artefacts
  5: ring_stage
"""

thin_yaml_path = f"{OUTPUT_ROOT}/thin_smear/data.yaml"
with open(thin_yaml_path, "w") as f:
    f.write(thin_data_yaml.strip())

print(f"✓ Created: {thin_yaml_path}")
print("\nContents:")
print(thin_data_yaml)
# Out:
# ✓ Created: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/data.yaml
#
# Contents:
#
# # Thin Smear Dataset for YOLO Training
# # Experiment: retrain_v2_yolov8s_100ep_1280px
#
# path: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear
# train: train/images
# val: val/images
#
# # Classes (same as baseline)
# names:
#   0: gametocyte
#   1: trophozoite
#   2: other_stage
#   3: white_blood_cell
#   4: artefacts
#   5: ring_stage

# %%
# Create data.yaml for thick smear evaluation
thick_data_yaml = f"""
# Thick Smear Dataset for OOD Evaluation
# Experiment: {EXPERIMENT_NAME}

path: {OUTPUT_ROOT}/thick_smear_test
train: images  # Not used, but required by YOLO
val: images

# Classes (same as baseline)
names:
  0: gametocyte
  1: trophozoite
  2: other_stage
  3: white_blood_cell
  4: artefacts
  5: ring_stage
"""

thick_yaml_path = f"{OUTPUT_ROOT}/thick_smear_test/data.yaml"
with open(thick_yaml_path, "w") as f:
    f.write(thick_data_yaml.strip())

print(f"✓ Created: {thick_yaml_path}")
# Out:
# ✓ Created: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/data.yaml

# %% [markdown]
# ## 5. Training (with New Hyperparameters)
#
# **Estimated time on L4 GPU:** ~2-4 hours for 100 epochs at 1280px

# %%
from ultralytics import YOLO

# Record start time
start_time = datetime.now()
print(f"Training started at: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
print("="*60)
print(f"Model: YOLOv8{MODEL_SIZE}")
print(f"Epochs: {EPOCHS}")
print(f"Image size: {IMAGE_SIZE}")
print(f"Batch size: {BATCH_SIZE}")
print("="*60 + "\n")

# Initialize model (YOLOv8s instead of YOLOv8n)
model = YOLO(f'yolov8{MODEL_SIZE}.pt')

# Train with new hyperparameters
results = model.train(
    data=thin_yaml_path,
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH_SIZE,
    project=RESULTS_DIR,
    name=EXPERIMENT_NAME,
    patience=PATIENCE,
    save=True,
    plots=True,
    verbose=True,
    # Optimizer settings
    optimizer='AdamW',
    lr0=0.01,
    lrf=0.01,
    warmup_epochs=3,
    # Augmentation (same as default)
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    translate=0.1,
    scale=0.5,
    fliplr=0.5,
    mosaic=1.0,
)

# Record end time
end_time = datetime.now()
duration = end_time - start_time

print("\n" + "="*60)
print(f"Training completed at: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total duration: {duration}")
print(f"\nResults saved to: {RESULTS_DIR}/{EXPERIMENT_NAME}")
# Out:
# Training started at: 2025-12-09 10:24:25
# ============================================================
# Model: YOLOv8s
# Epochs: 100
# Image size: 1280
# Batch size: 16
# ============================================================
#
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=retrain_v2_yolov8s_100ep_1280px2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/Datasets/malaria_results, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# Model summary: 129 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 427.7±329.7 MB/s, size: 2852.1 KB)
# train: Scanning /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/labels.cache... 808 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 808/808 882.8Kit/s 0.0s
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1001.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1005.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1010.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1011.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1012.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1013.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1016.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1018.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1023.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1024.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1025.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1026.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1027.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1030.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1036.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1038.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1039.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1041.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1043.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1045.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1048.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1052.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1053.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1057.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1059.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1064.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1065.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1067.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1068.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1069.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1073.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1074.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1075.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1076.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1079.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1081.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1083.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1086.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1088.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/109.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1093.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1094.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1095.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1097.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1098.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/110.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1101.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1102.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1107.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1108.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1111.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1113.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1115.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1116.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1117.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1118.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1119.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1122.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1123.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1124.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1126.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1135.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1141.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1143.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1146.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1148.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1149.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1150.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1151.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1158.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1161.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1162.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1166.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1168.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1170.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1171.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1172.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1173.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1174.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1178.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1180.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1184.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1189.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1191.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1194.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1196.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1197.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1200.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1205.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1207.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1210.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1211.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1212.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1213.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1217.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1221.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1222.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1227.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1230.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1231.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1232.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1240.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1241.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1244.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1247.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1248.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1249.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1250.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1251.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1256.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1258.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1259.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1262.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1265.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1268.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1269.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1270.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1273.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1274.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1278.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1282.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1286.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1289.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1295.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1298.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1300.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1302.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1303.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1305.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1306.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1307.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1311.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1317.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1318.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1319.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/132.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1320.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1324.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1326.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1328.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1329.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1330.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1331.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1332.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1334.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1336.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1337.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1339.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1342.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1343.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1345.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1348.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1349.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/135.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1351.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1354.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1355.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1357.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1360.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1361.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1362.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1363.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1364.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1367.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1368.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1369.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1370.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1373.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1374.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1377.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1378.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1381.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1384.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1385.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1386.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1389.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1390.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1392.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1396.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1398.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1399.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1403.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1404.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1406.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1412.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1413.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1414.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1417.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1419.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1420.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1427.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1428.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1430.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1434.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1435.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1436.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1438.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/144.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1442.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1446.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1447.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1450.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1453.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1460.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1462.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1463.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1466.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1468.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1471.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1473.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1475.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1476.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1478.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1480.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1481.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1485.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1487.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1490.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1493.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1495.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1498.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1501.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1502.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1505.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1506.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1507.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1509.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1510.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1511.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1514.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1515.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1517.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1518.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1524.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1531.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1536.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1539.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1540.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1541.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1551.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1552.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1553.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1554.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1555.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1557.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1558.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1560.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1562.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1563.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1565.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/1566.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/162.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/165.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/166.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/168.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/172.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/173.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/174.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/175.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/180.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/185.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/192.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/205.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/215.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/220.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/221.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/224.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/230.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/233.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/237.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/238.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/239.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/244.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/253.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/259.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/267.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/268.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/27.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/283.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/291.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/293.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/294.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/295.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/305.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/307.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/310.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/315.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/335.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/341.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/342.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/344.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/345.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/346.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/348.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/363.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/368.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/380.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/406.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/410.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/430.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/474.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/481.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/484.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/494.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/5.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/51.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/510.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/514.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/516.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/519.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/523.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/536.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/538.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/547.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/549.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/550.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/556.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/559.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/565.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/574.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/581.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/582.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/583.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/584.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/585.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/587.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/59.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/590.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/592.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/595.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/599.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/6.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/603.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/606.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/607.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/608.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/609.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/610.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/612.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/613.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/614.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/616.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/617.jpg: corrupt JPEG restored and saved
# train: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/train/images/62.jpg: corrupt JPEG restored and saved
# ...
#                    all        203       9520      0.332      0.337       0.29      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100        38G      2.565      2.166      1.122        488       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520      0.351      0.328      0.273      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100        38G      2.563      2.125      1.117        523       1280: 100% ━━━━━━━━━━━━ 51/51 2.2it/s 23.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.9it/s 2.4s
#                    all        203       9520      0.373      0.337      0.289      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100        38G      2.565      2.111      1.113        460       1280: 100% ━━━━━━━━━━━━ 51/51 2.2it/s 22.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520       0.33      0.338      0.297      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100        38G      2.564      2.139       1.14        501       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.356      0.339      0.271      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100        38G      2.538      2.068      1.109        455       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.395      0.334      0.302      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100        38G      2.548      2.103       1.12        268       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.357      0.326      0.304      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100        38G      2.528      2.073      1.108        356       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520      0.367       0.34      0.285      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100        38G      2.546      2.095      1.107        352       1280: 100% ━━━━━━━━━━━━ 51/51 2.6it/s 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.349      0.346      0.306       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100        38G      2.551      2.095      1.109        399       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.352      0.345        0.3      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100        38G      2.526      2.072      1.108        180       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.389      0.332      0.302      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100        38G      2.576      2.109      1.125        504       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520       0.45      0.331      0.309      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100        38G      2.528       2.08      1.115        560       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520      0.317      0.342      0.299      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100        38G      2.562      2.077      1.108        737       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.359       0.34      0.306      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100        38G      2.561      2.099      1.107        573       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.363      0.352      0.303       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100        38G      2.527      2.082      1.115        480       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 21.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520       0.38      0.329       0.31      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100        38G      2.534      2.058      1.111        645       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.427      0.325      0.305      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100        38G      2.534      2.053      1.108        616       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520      0.365      0.343      0.313      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100        38G      2.535       2.05      1.114        325       1280: 100% ━━━━━━━━━━━━ 51/51 2.2it/s 22.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520       0.36      0.363      0.305      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100        38G      2.537      2.086      1.131        499       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520      0.384      0.341      0.306      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100        38G      2.529      2.041      1.104        531       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.377      0.344      0.314      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100        38G      2.533      2.065      1.122        848       1280: 100% ━━━━━━━━━━━━ 51/51 2.6it/s 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520       0.39      0.327      0.315      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100        38G        2.5      2.023      1.105        549       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520      0.419      0.332      0.304      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100        38G      2.516      2.026      1.109        754       1280: 100% ━━━━━━━━━━━━ 51/51 2.2it/s 23.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.346      0.348      0.313      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100        38G      2.507      2.034      1.108        469       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 21.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.354      0.341      0.307      0.133
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100        38G      2.488      2.094      1.156        250       1280: 100% ━━━━━━━━━━━━ 51/51 2.0it/s 25.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520      0.385      0.335      0.311      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100        38G       2.48      2.076      1.154        282       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520      0.369      0.358      0.315      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100        38G      2.495      2.054      1.142        508       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.369      0.353      0.313      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100        38G      2.486      2.083      1.146        217       1280: 100% ━━━━━━━━━━━━ 51/51 2.4it/s 21.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.388      0.352      0.316      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100        38G      2.488      2.058      1.139        499       1280: 100% ━━━━━━━━━━━━ 51/51 2.5it/s 20.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520      0.348      0.358      0.315      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100        38G      2.473      2.049      1.138        371       1280: 100% ━━━━━━━━━━━━ 51/51 2.2it/s 22.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        203       9520      0.399      0.337      0.315      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100        38G      2.473      2.058      1.147        228       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        203       9520       0.39      0.351       0.32      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100        38G       2.48      2.055      1.147        311       1280: 100% ━━━━━━━━━━━━ 51/51 2.6it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        203       9520      0.367      0.359      0.316      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100        38G      2.459      2.036      1.141        237       1280: 100% ━━━━━━━━━━━━ 51/51 2.6it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520      0.344      0.373      0.323       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100        38G      2.463      2.037      1.144        445       1280: 100% ━━━━━━━━━━━━ 51/51 2.3it/s 22.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.8it/s 2.5s
#                    all        203       9520       0.34      0.375       0.32      0.139
#
# 100 epochs completed in 0.718 hours.
# Optimizer stripped from /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px2/weights/last.pt, 22.6MB
# Optimizer stripped from /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px2/weights/best.pt, 22.6MB
#
# Validating /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px2/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 72 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3s/it 9.4s
#                    all        203       9520      0.344      0.373      0.323       0.14
#             gametocyte        135       3234      0.242      0.173      0.136     0.0465
#            trophozoite        103       3100      0.268     0.0535     0.0714     0.0242
#       white_blood_cell        126        280      0.632      0.864      0.851      0.444
#              artefacts         25         42       0.27        0.5      0.343      0.117
#             ring_stage         85       2864      0.309      0.274      0.213     0.0665
# Speed: 0.4ms preprocess, 2.4ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px2
#
# ============================================================
# Training completed at: 2025-12-09 11:07:57
# Total duration: 0:43:31.587695
#
# Results saved to: /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px

# %% [markdown]
# ## 6. Load Trained Model

# %%
# Path to best weights
BEST_WEIGHTS = f"{RESULTS_DIR}/{EXPERIMENT_NAME}/weights/best.pt"

# Check if weights exist
if os.path.exists(BEST_WEIGHTS):
    print(f"✓ Best weights found: {BEST_WEIGHTS}")
    model = YOLO(BEST_WEIGHTS)
else:
    print(f"✗ Weights not found at: {BEST_WEIGHTS}")
    print("Make sure training completed successfully.")
# Out:
# ✓ Best weights found: /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px/weights/best.pt

# %% [markdown]
# ## 7. Evaluation: Thin Smears (In-Distribution)

# %%
# Evaluate on thin smears (validation set = in-distribution)
print("="*60)
print("EVALUATING ON THIN SMEARS (In-Distribution)")
print("="*60)

results_thin = model.val(
    data=thin_yaml_path,
    split='val',
    imgsz=IMAGE_SIZE,
    project=RESULTS_DIR,
    name=f'{EXPERIMENT_NAME}_eval_thin',
    plots=True,
)

# Store results
id_map50 = results_thin.box.map50
id_map = results_thin.box.map

print("\n" + "="*60)
print("THIN SMEAR RESULTS (In-Distribution)")
print("="*60)
print(f"mAP@0.5:      {id_map50:.4f}")
print(f"mAP@0.5:0.95: {id_map:.4f}")
print(f"Precision:    {results_thin.box.mp:.4f}")
print(f"Recall:       {results_thin.box.mr:.4f}")
print("\nPer-class AP@0.5:")
for i, ap in enumerate(results_thin.box.ap50):
    print(f"  {CLASS_NAMES[i]}: {ap:.4f}")
# Out:
# ============================================================
# EVALUATING ON THIN SMEARS (In-Distribution)
# ============================================================
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# Model summary (fused): 72 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 8.2±17.5 ms, read: 581.0±330.8 MB/s, size: 3647.4 KB)
# val: Scanning /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 203/203 254.8Kit/s 0.0s
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1003.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1007.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1009.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/102.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1021.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1046.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1047.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1050.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1070.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1096.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1105.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1106.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1109.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1125.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1136.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1139.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1142.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1175.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1187.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/12.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1204.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1208.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1216.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1220.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1225.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1226.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1229.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1238.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1254.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1255.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1271.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1276.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1280.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/129.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1308.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1310.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1322.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1323.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1335.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1338.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1353.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1387.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1402.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1421.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1433.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1437.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1440.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1449.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/146.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1484.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1486.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1489.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/149.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1494.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1503.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1532.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1535.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1537.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1538.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/154.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1543.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/1549.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/181.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/203.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/204.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/228.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/255.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/260.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/306.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/32.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/331.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/383.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/423.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/464.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/512.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/524.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/575.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/577.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/598.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/600.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/604.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/627.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/641.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/654.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/655.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/66.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/663.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/683.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/696.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/702.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/710.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/715.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/719.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/727.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/752.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/762.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/766.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/768.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/774.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/776.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/779.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/780.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/79.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/790.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/800.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/802.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/806.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/815.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/816.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/823.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/834.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/836.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/843.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/848.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/849.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/856.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/868.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/870.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/875.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/881.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/886.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/892.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/894.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/898.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/901.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/909.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/914.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/928.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/930.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/943.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/947.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/961.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/971.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/980.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thin_smear/val/images/981.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.0s/it 13.0s
#                    all        203       9520      0.344       0.37      0.322       0.14
#             gametocyte        135       3234      0.243      0.172      0.138     0.0475
#            trophozoite        103       3100      0.266     0.0528     0.0725     0.0249
#       white_blood_cell        126        280      0.631      0.854      0.843      0.444
#              artefacts         25         42       0.27        0.5      0.345      0.115
#             ring_stage         85       2864      0.312      0.273      0.214     0.0668
# Speed: 6.5ms preprocess, 3.9ms inference, 0.0ms loss, 13.3ms postprocess per image
# Results saved to /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px_eval_thin2
#
# ============================================================
# THIN SMEAR RESULTS (In-Distribution)
# ============================================================
# mAP@0.5:      0.3225
# mAP@0.5:0.95: 0.1395
# Precision:    0.3444
# Recall:       0.3702
#
# Per-class AP@0.5:
#   gametocyte: 0.1382
#   trophozoite: 0.0725
#   other_stage: 0.8430
#   white_blood_cell: 0.3450
#   artefacts: 0.2135

# %% [markdown]
# ## 8. Evaluation: Thick Smears (Out-of-Distribution)

# %%
# Evaluate on thick smears (test set = out-of-distribution)
print("="*60)
print("EVALUATING ON THICK SMEARS (Out-of-Distribution)")
print("="*60)

results_thick = model.val(
    data=thick_yaml_path,
    split='val',
    imgsz=IMAGE_SIZE,
    project=RESULTS_DIR,
    name=f'{EXPERIMENT_NAME}_eval_thick',
    plots=True,
)

# Store results
ood_map50 = results_thick.box.map50
ood_map = results_thick.box.map

print("\n" + "="*60)
print("THICK SMEAR RESULTS (Out-of-Distribution)")
print("="*60)
print(f"mAP@0.5:      {ood_map50:.4f}")
print(f"mAP@0.5:0.95: {ood_map:.4f}")
print(f"Precision:    {results_thick.box.mp:.4f}")
print(f"Recall:       {results_thick.box.mr:.4f}")
print("\nPer-class AP@0.5:")
for i, ap in enumerate(results_thick.box.ap50):
    print(f"  {CLASS_NAMES[i]}: {ap:.4f}")
# Out:
# ============================================================
# EVALUATING ON THICK SMEARS (Out-of-Distribution)
# ============================================================
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-80GB, 81222MiB)
# val: Fast image access ✅ (ping: 0.3±0.0 ms, read: 733.2±159.1 MB/s, size: 4548.7 KB)
# val: Scanning /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/labels.cache... 3045 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3045/3045 3.7Mit/s 0.0s
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/0.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/10.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/100.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1000.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1001.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1002.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1003.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1004.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1005.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1006.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1007.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1008.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1009.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/101.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1010.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1011.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1012.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1013.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1014.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1015.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1016.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1017.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1018.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1019.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/102.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1020.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1021.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1022.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1023.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1024.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1025.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1026.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1027.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1028.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1029.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/103.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1030.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1031.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1032.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1033.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1034.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1035.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1036.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1037.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1039.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/104.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1040.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1041.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1042.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1043.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1044.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1045.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1046.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1047.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1048.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1049.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/105.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1050.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1051.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1052.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1053.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1054.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1055.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1056.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1057.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1058.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1059.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/106.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1060.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1061.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1062.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1063.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1064.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1065.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1066.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1067.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1068.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1069.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/107.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1070.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1071.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1072.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1073.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1074.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1075.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1077.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1078.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1079.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/108.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1080.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1082.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1083.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1084.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1086.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1087.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1088.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1089.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/109.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1090.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1091.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1092.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1093.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1094.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1095.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1096.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1097.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1098.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1099.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/11.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/110.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1100.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1101.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1102.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1103.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1104.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1106.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1107.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1108.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1109.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/111.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1110.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1111.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1112.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1113.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1114.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1115.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1116.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1117.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1118.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1119.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/112.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1120.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1121.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1122.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1123.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1124.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1125.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1126.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1127.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1128.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1129.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/113.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1130.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1131.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1132.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1133.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1134.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1135.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1136.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1137.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1138.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1139.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/114.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1140.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1141.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1142.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1143.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1144.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1145.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1146.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1147.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1148.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1149.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/115.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1150.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1151.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1152.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1153.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1154.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1155.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1156.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1157.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1158.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/116.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1160.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1161.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1162.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1163.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1164.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1165.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1166.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1167.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1168.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1169.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/117.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1170.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1171.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1172.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1173.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1174.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1175.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1176.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1177.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1178.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1179.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/118.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1180.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1181.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1182.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1183.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1184.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1186.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1187.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1188.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1189.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/119.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1190.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1191.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1192.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1193.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1194.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1195.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1196.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1197.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1198.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1199.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/12.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/120.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1200.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1201.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1202.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1203.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1204.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1205.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1206.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1207.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1208.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1209.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/121.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1210.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1211.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1212.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1213.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1214.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1216.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1217.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1218.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1219.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/122.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1221.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1222.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1223.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1224.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1225.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1226.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1227.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1228.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1229.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/123.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1230.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1231.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1232.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1233.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1234.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1235.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1236.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1237.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1238.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1239.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/124.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1240.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1241.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1242.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1243.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1244.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1245.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1246.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1247.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1248.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1249.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/125.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1250.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1251.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1252.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1253.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1254.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1255.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1256.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1257.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1258.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1259.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/126.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1260.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1261.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1262.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1263.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1264.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1265.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1266.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1267.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1268.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1269.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/127.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1270.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1271.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1272.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1273.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1274.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1275.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1276.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1277.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1278.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1279.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/128.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1280.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1281.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1283.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1284.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1285.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1286.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1287.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1288.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1289.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/129.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1290.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1291.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1292.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1293.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1294.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1295.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1297.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1299.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/13.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/130.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1300.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1301.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1302.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1303.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1304.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1305.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1306.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1307.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1308.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1309.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/131.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1310.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1311.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1312.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1313.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1314.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1316.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1317.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1318.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1319.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/132.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1320.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1321.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1322.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1323.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1324.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1325.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1326.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1327.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1328.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1329.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/133.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1330.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1331.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1332.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1333.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1334.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1335.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1336.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1337.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1338.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1339.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/134.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1340.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1341.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1342.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1343.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1344.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1345.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1346.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1347.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1348.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1349.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/135.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1350.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1351.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1352.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1353.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1354.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1355.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1356.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1357.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/1359.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/136.jpg: corrupt JPEG restored and saved
# ...
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/882.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/883.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/884.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/885.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/886.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/887.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/888.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/889.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/89.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/890.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/891.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/892.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/893.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/894.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/895.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/896.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/897.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/898.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/899.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/9.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/90.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/900.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/901.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/902.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/903.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/904.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/905.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/907.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/908.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/909.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/91.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/910.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/911.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/912.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/913.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/914.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/915.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/916.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/917.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/918.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/919.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/92.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/920.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/921.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/922.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/923.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/924.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/925.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/926.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/927.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/928.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/929.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/93.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/930.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/931.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/932.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/933.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/934.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/935.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/936.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/937.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/938.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/939.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/94.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/941.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/942.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/943.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/944.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/945.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/946.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/947.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/948.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/949.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/95.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/950.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/951.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/952.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/953.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/954.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/955.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/956.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/957.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/958.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/96.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/960.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/961.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/962.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/963.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/964.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/966.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/967.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/968.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/969.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/97.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/970.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/971.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/972.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/973.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/974.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/975.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/976.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/977.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/978.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/979.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/980.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/981.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/982.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/983.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/984.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/985.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/986.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/987.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/988.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/989.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/99.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/990.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/991.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/992.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/994.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/995.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/996.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/997.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/998.jpg: corrupt JPEG restored and saved
# val: /content/drive/MyDrive/Datasets/malaria_yolo_ready/thick_smear_test/images/999.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 191/191 1.9it/s 1:43
#                    all       3045     377166      0.147      0.221       0.11     0.0445
#             gametocyte       3039     360900      0.293       0.44      0.219     0.0887
#            trophozoite       2696      16266   0.000264    0.00203   0.000587   0.000305
# Speed: 2.4ms preprocess, 3.1ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px_eval_thick2
#
# ============================================================
# THICK SMEAR RESULTS (Out-of-Distribution)
# ============================================================
# mAP@0.5:      0.1096
# mAP@0.5:0.95: 0.0445
# Precision:    0.1465
# Recall:       0.2211
#
# Per-class AP@0.5:
#   gametocyte: 0.2187
#   trophozoite: 0.0006

# %%
# ============================================================
# 8.5 COLLAPSED CLASS EVALUATION
# Merge all parasite classes into one "parasite" class
# to match thick smear annotation scheme from datasheet
# ============================================================

import os
from pathlib import Path
from collections import defaultdict

# Define class mapping
# Original: 0=gametocyte, 1=trophozoite, 2=other_stage, 3=wbc, 4=artefacts, 5=ring_stage
# Collapsed: 0=parasite, 1=wbc, 2=artefacts

COLLAPSE_MAP = {
    0: 0,  # gametocyte → parasite
    1: 0,  # trophozoite → parasite
    2: 0,  # other_stage → parasite
    3: 1,  # white_blood_cell → white_blood_cell
    4: 2,  # artefacts → artefacts
    5: 0,  # ring_stage → parasite
}

COLLAPSED_NAMES = {
    0: "parasite",
    1: "white_blood_cell",
    2: "artefacts"
}

print("="*60)
print("COLLAPSED CLASS EVALUATION")
print("Merging parasite stages to match thick smear annotations")
print("="*60)
print("\nClass Mapping:")
for orig, new in COLLAPSE_MAP.items():
    print(f"  {CLASS_NAMES[orig]} → {COLLAPSED_NAMES[new]}")

# Run inference on thick smears
thick_images_path = f"{OUTPUT_ROOT}/thick_smear_test/images"
thick_labels_path = f"{OUTPUT_ROOT}/thick_smear_test/labels"

print(f"\nRunning inference on thick smears...")
results = model.predict(
    source=thick_images_path,
    imgsz=IMAGE_SIZE,
    conf=0.25,
    save=False,
    verbose=False
)
print(f"✓ Processed {len(results)} images")

# Calculate collapsed metrics
stats = defaultdict(lambda: {"TP": 0, "FP": 0, "FN": 0})

for result in results:
    img_name = Path(result.path).stem
    label_file = os.path.join(thick_labels_path, f"{img_name}.txt")

    # Get predictions (collapsed)
    pred_classes = []
    if result.boxes is not None and len(result.boxes) > 0:
        for box in result.boxes:
            cls = int(box.cls.item())
            collapsed_cls = COLLAPSE_MAP.get(cls, cls)
            pred_classes.append(collapsed_cls)

    # Get ground truth (collapsed)
    gt_classes = []
    if os.path.exists(label_file):
        with open(label_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) >= 5:
                    cls = int(parts[0])
                    collapsed_cls = COLLAPSE_MAP.get(cls, cls)
                    gt_classes.append(collapsed_cls)

    # Count per class
    for cls in set(pred_classes + gt_classes):
        pred_count = pred_classes.count(cls)
        gt_count = gt_classes.count(cls)

        tp = min(pred_count, gt_count)
        fp = max(0, pred_count - gt_count)
        fn = max(0, gt_count - pred_count)

        stats[cls]["TP"] += tp
        stats[cls]["FP"] += fp
        stats[cls]["FN"] += fn

# Print results
print("\n" + "="*60)
print("COLLAPSED CLASS RESULTS (Thick Smears)")
print("="*60)
print(f"{'Class':<20} {'Precision':<12} {'Recall':<12} {'TP':<8} {'FP':<8} {'FN':<8}")
print("-"*68)

total_tp, total_fp, total_fn = 0, 0, 0
for cls_id in sorted(stats.keys()):
    s = stats[cls_id]
    precision = s["TP"] / (s["TP"] + s["FP"]) if (s["TP"] + s["FP"]) > 0 else 0
    recall = s["TP"] / (s["TP"] + s["FN"]) if (s["TP"] + s["FN"]) > 0 else 0
    name = COLLAPSED_NAMES.get(cls_id, f'class_{cls_id}')
    print(f"{name:<20} {precision:<12.4f} {recall:<12.4f} {s['TP']:<8} {s['FP']:<8} {s['FN']:<8}")
    total_tp += s["TP"]
    total_fp += s["FP"]
    total_fn += s["FN"]

# Overall
print("-"*68)
overall_precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
overall_recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
print(f"{'OVERALL':<20} {overall_precision:<12.4f} {overall_recall:<12.4f} {total_tp:<8} {total_fp:<8} {total_fn:<8}")

print("\n" + "="*60)
print("INTERPRETATION")
print("="*60)
parasite_recall = stats[0]["TP"] / (stats[0]["TP"] + stats[0]["FN"]) if (stats[0]["TP"] + stats[0]["FN"]) > 0 else 0
print(f"Parasite recall (collapsed): {parasite_recall:.1%}")
if parasite_recall > 0.3:
    print("→ Label mismatch was significant factor in poor OOD performance")
else:
    print("→ True visual domain shift: model cannot detect parasites in thick smears")
# Out:
# ============================================================
# COLLAPSED CLASS EVALUATION
# Merging parasite stages to match thick smear annotations
# ============================================================
#
# Class Mapping:
#   gametocyte → parasite
#   trophozoite → parasite
#   other_stage → parasite
#   white_blood_cell → white_blood_cell
#   artefacts → artefacts
#   ring_stage → parasite
#
# Running inference on thick smears...
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

# %% [markdown]
# ## 9. Comparison: Baseline vs Retrain v2

# %%
# Baseline results (from your previous experiment)
# These are your actual numbers from the first run

baseline_thin = {
    'mAP50': 0.3150,
    'gametocyte': 0.087,
    'trophozoite': 0.077,
    'other_stage': 0.0,      # Update if you have this
    'white_blood_cell': 0.844,
    'artefacts': 0.416,
    'ring_stage': 0.151,
}

baseline_thick = {
    'mAP50': 0.2627,
    'gametocyte': 0.524,
    'trophozoite': 0.0009,
}

print("Baseline results loaded from your first experiment.")
# Out:
# Baseline results loaded from your first experiment.

# %%
# Create comparison table
import pandas as pd

print("="*70)
print("COMPARISON: BASELINE vs RETRAIN v2")
print("="*70)

# Overall comparison
print("\n📊 OVERALL PERFORMANCE")
print("-"*70)
print(f"{'Metric':<30} {'Baseline':<15} {'Retrain v2':<15} {'Change':<15}")
print("-"*70)

# Thin smear comparison
change_thin = id_map50 - baseline_thin['mAP50']
change_thin_pct = (change_thin / baseline_thin['mAP50']) * 100
print(f"{'mAP@0.5 (Thin/ID)':<30} {baseline_thin['mAP50']:<15.4f} {id_map50:<15.4f} {change_thin:+.4f} ({change_thin_pct:+.1f}%)")

# Thick smear comparison
change_thick = ood_map50 - baseline_thick['mAP50']
change_thick_pct = (change_thick / baseline_thick['mAP50']) * 100
print(f"{'mAP@0.5 (Thick/OOD)':<30} {baseline_thick['mAP50']:<15.4f} {ood_map50:<15.4f} {change_thick:+.4f} ({change_thick_pct:+.1f}%)")

# Domain shift comparison
baseline_drop = ((baseline_thin['mAP50'] - baseline_thick['mAP50']) / baseline_thin['mAP50']) * 100
retrain_drop = ((id_map50 - ood_map50) / id_map50) * 100 if id_map50 > 0 else 0
print(f"{'Domain Shift Drop':<30} {baseline_drop:<15.1f}% {retrain_drop:<15.1f}%")
# Out:
# ======================================================================
# COMPARISON: BASELINE vs RETRAIN v2
# ======================================================================
#
# 📊 OVERALL PERFORMANCE
# ----------------------------------------------------------------------
# Metric                         Baseline        Retrain v2      Change
# ----------------------------------------------------------------------
# mAP@0.5 (Thin/ID)              0.3150          0.3225          +0.0075 (+2.4%)
# mAP@0.5 (Thick/OOD)            0.2627          0.1096          -0.1531 (-58.3%)
# Domain Shift Drop              16.6           % 66.0           %

# %%
# Per-class comparison
print("\n📊 PER-CLASS COMPARISON (Thin Smears)")
print("-"*70)
print(f"{'Class':<20} {'Baseline':<15} {'Retrain v2':<15} {'Change':<15}")
print("-"*70)

retrain_thin_per_class = {CLASS_NAMES[i]: ap for i, ap in enumerate(results_thin.box.ap50)}

for cls_name in CLASS_NAMES.values():
    baseline_val = baseline_thin.get(cls_name, 0)
    retrain_val = retrain_thin_per_class.get(cls_name, 0)
    change = retrain_val - baseline_val
    change_pct = (change / baseline_val) * 100 if baseline_val > 0 else 0
    print(f"{cls_name:<20} {baseline_val:<15.4f} {retrain_val:<15.4f} {change:+.4f} ({change_pct:+.1f}%)")
# Out:
# 📊 PER-CLASS COMPARISON (Thin Smears)
# ----------------------------------------------------------------------
# Class                Baseline        Retrain v2      Change
# ----------------------------------------------------------------------
# gametocyte           0.0870          0.1382          +0.0512 (+58.9%)
# trophozoite          0.0770          0.0725          -0.0045 (-5.8%)
# other_stage          0.0000          0.8430          +0.8430 (+0.0%)
# white_blood_cell     0.8440          0.3450          -0.4990 (-59.1%)
# artefacts            0.4160          0.2135          -0.2025 (-48.7%)
# ring_stage           0.1510          0.0000          -0.1510 (-100.0%)

# %%
# Visualize comparison
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Overall mAP comparison
ax1 = axes[0]
metrics = ['Thin (ID)', 'Thick (OOD)']
baseline_vals = [baseline_thin['mAP50'], baseline_thick['mAP50']]
retrain_vals = [id_map50, ood_map50]

x = np.arange(len(metrics))
width = 0.35

bars1 = ax1.bar(x - width/2, baseline_vals, width, label='Baseline (YOLOv8n, 50ep, 640px)', color='#3182ce')
bars2 = ax1.bar(x + width/2, retrain_vals, width, label='Retrain v2 (YOLOv8s, 100ep, 1280px)', color='#e53e3e')

ax1.set_ylabel('mAP@0.5')
ax1.set_title('Overall Performance: Baseline vs Retrain v2')
ax1.set_xticks(x)
ax1.set_xticklabels(metrics)
ax1.legend()
ax1.set_ylim(0, 1.0)

for bar in bars1 + bars2:
    height = bar.get_height()
    ax1.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width()/2, height),
                 xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', fontsize=10)

# Plot 2: Per-class comparison (thin smears)
ax2 = axes[1]
classes = list(CLASS_NAMES.values())
baseline_class_vals = [baseline_thin.get(c, 0) for c in classes]
retrain_class_vals = [retrain_thin_per_class.get(c, 0) for c in classes]

x2 = np.arange(len(classes))
bars3 = ax2.bar(x2 - width/2, baseline_class_vals, width, label='Baseline', color='#3182ce')
bars4 = ax2.bar(x2 + width/2, retrain_class_vals, width, label='Retrain v2', color='#e53e3e')

ax2.set_ylabel('AP@0.5')
ax2.set_title('Per-Class Performance on Thin Smears')
ax2.set_xticks(x2)
ax2.set_xticklabels(classes, rotation=45, ha='right')
ax2.legend()
ax2.set_ylim(0, 1.0)

plt.tight_layout()

# Save figure
fig_path = f"{RESULTS_DIR}/{EXPERIMENT_NAME}/baseline_vs_retrain_comparison.png"
os.makedirs(os.path.dirname(fig_path), exist_ok=True)
plt.savefig(fig_path, dpi=150, bbox_inches='tight')
print(f"\n📊 Saved: {fig_path}")

plt.show()
# Out:
# 📊 Saved: /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px/baseline_vs_retrain_comparison.png

# %% [markdown]
# ## 10. Summary & Interpretation

# %%
# Generate summary
print("="*70)
print("EXPERIMENT SUMMARY")
print("="*70)

print(f"""
HYPOTHESES TESTED:
  H1: Larger model (YOLOv8s vs YOLOv8n) improves parasite detection
  H2: More training (100 vs 50 epochs) reduces underfitting
  H3: Higher resolution (1280 vs 640) helps small object detection

SETUP:
  • Baseline: YOLOv8n, 50 epochs, 640px
  • Retrain:  YOLOv8s, 100 epochs, 1280px
  • Training: {train_n} thin smear images
  • Test (ID): {val_n} thin smear images
  • Test (OOD): {test_n} thick smear images

RESULTS:
  Thin Smears (In-Distribution):
    • Baseline mAP@0.5: {baseline_thin['mAP50']:.4f}
    • Retrain mAP@0.5:  {id_map50:.4f}
    • Change: {change_thin:+.4f} ({change_thin_pct:+.1f}%)

  Thick Smears (Out-of-Distribution):
    • Baseline mAP@0.5: {baseline_thick['mAP50']:.4f}
    • Retrain mAP@0.5:  {ood_map50:.4f}
    • Change: {change_thick:+.4f} ({change_thick_pct:+.1f}%)

  Domain Shift:
    • Baseline drop: {baseline_drop:.1f}%
    • Retrain drop:  {retrain_drop:.1f}%
""")

# Interpretation
print("INTERPRETATION:")
print("-"*70)

if change_thin_pct > 10:
    print("✅ H1/H2/H3 SUPPORTED: Larger model and more training improved performance.")
    if retrain_drop < baseline_drop:
        print("✅ Domain shift improved: Better generalization to thick smears.")
    else:
        print("⚠️ Domain shift persists: Better ID performance doesn't help OOD.")
elif change_thin_pct > 0:
    print("⚠️ PARTIAL SUPPORT: Slight improvement, but not substantial.")
    print("   The problem may be more fundamental (data size, annotation quality).")
else:
    print("❌ HYPOTHESES NOT SUPPORTED: Larger model didn't help.")
    print("   The problem is likely data-related, not model capacity.")

print("\n" + "="*70)
# Out:
# ======================================================================
# EXPERIMENT SUMMARY
# ======================================================================
#
# HYPOTHESES TESTED:
#   H1: Larger model (YOLOv8s vs YOLOv8n) improves parasite detection
#   H2: More training (100 vs 50 epochs) reduces underfitting
#   H3: Higher resolution (1280 vs 640) helps small object detection
#
# SETUP:
#   • Baseline: YOLOv8n, 50 epochs, 640px
#   • Retrain:  YOLOv8s, 100 epochs, 1280px
#   • Training: 808 thin smear images
#   • Test (ID): 203 thin smear images
#   • Test (OOD): 3045 thick smear images
#
# RESULTS:
#   Thin Smears (In-Distribution):
#     • Baseline mAP@0.5: 0.3150
#     • Retrain mAP@0.5:  0.3225
#     • Change: +0.0075 (+2.4%)
#
#   Thick Smears (Out-of-Distribution):
#     • Baseline mAP@0.5: 0.2627
#     • Retrain mAP@0.5:  0.1096
#     • Change: -0.1531 (-58.3%)
#
#   Domain Shift:
#     • Baseline drop: 16.6%
#     • Retrain drop:  66.0%
#
# INTERPRETATION:
# ----------------------------------------------------------------------
# ⚠️ PARTIAL SUPPORT: Slight improvement, but not substantial.
#    The problem may be more fundamental (data size, annotation quality).
#
# ======================================================================

# %%
# Save summary to file
summary_path = f"{RESULTS_DIR}/{EXPERIMENT_NAME}/experiment_summary.txt"

with open(summary_path, 'w') as f:
    f.write(f"EXPERIMENT SUMMARY: {EXPERIMENT_NAME}\n")
    f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("="*70 + "\n\n")
    f.write(f"CONFIGURATION\n")
    f.write(f"Model: YOLOv8{MODEL_SIZE}\n")
    f.write(f"Epochs: {EPOCHS}\n")
    f.write(f"Image size: {IMAGE_SIZE}\n")
    f.write(f"Batch size: {BATCH_SIZE}\n\n")
    f.write(f"RESULTS\n")
    f.write(f"Thin (ID) mAP@0.5: {id_map50:.4f}\n")
    f.write(f"Thick (OOD) mAP@0.5: {ood_map50:.4f}\n\n")
    f.write(f"BASELINE COMPARISON\n")
    f.write(f"Thin change: {change_thin:+.4f} ({change_thin_pct:+.1f}%)\n")
    f.write(f"Thick change: {change_thick:+.4f} ({change_thick_pct:+.1f}%)\n")

print(f"✓ Summary saved to: {summary_path}")
# Out:
# ✓ Summary saved to: /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px/experiment_summary.txt

# %% [markdown]
# ## 11. Files Generated
#
# Check your results folder for all outputs.

# %%
# List all files in results folder
results_folder = f"{RESULTS_DIR}/{EXPERIMENT_NAME}"

print(f"Files in {results_folder}:\n")

if os.path.exists(results_folder):
    for root, dirs, files in os.walk(results_folder):
        level = root.replace(results_folder, '').count(os.sep)
        indent = ' ' * 2 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 2 * (level + 1)
        for file in files:
            print(f"{subindent}{file}")
else:
    print(f"Results folder not found: {results_folder}")
# Out:
# Files in /content/drive/MyDrive/Datasets/malaria_results/retrain_v2_yolov8s_100ep_1280px:
#
# retrain_v2_yolov8s_100ep_1280px/
#   args.yaml
#   labels.jpg
#   train_batch0.jpg
#   train_batch1.jpg
#   train_batch2.jpg
#   results.csv
#   train_batch4590.jpg
#   train_batch4591.jpg
#   train_batch4592.jpg
#   val_batch0_pred.jpg
#   val_batch2_pred.jpg
#   val_batch1_pred.jpg
#   val_batch2_labels.jpg
#   val_batch1_labels.jpg
#   val_batch0_labels.jpg
#   BoxPR_curve.png
#   BoxF1_curve.png
#   BoxP_curve.png
#   BoxR_curve.png
#   confusion_matrix_normalized.png
#   confusion_matrix.png
#   results.png
#   baseline_vs_retrain_comparison.png
#   experiment_summary.txt
#   weights/
#     last.pt
#     best.pt
